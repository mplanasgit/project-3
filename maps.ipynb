# %% [markdown]
# **Notebook to visualize the maps of each city**
#
# ---

# %% [markdown]
# **Libraries**

# %%
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd

# %% [markdown]
# **Datasets**

# %%
# Companies:
sanfran_companies = pd.read_csv('./data/companies_sanfrancisco_map.csv')
south_sanfran_companies = pd.read_csv('./data/companies_south_sanfrancisco_map.csv')
newyork_companies = pd.read_csv('./data/companies_newyork_map.csv')
london_companies = pd.read_csv('./data/companies_london_map.csv')

# %%
# Activities/Categories:
sanfran_activities = pd.read_csv("data/sanfrancisco_activities.csv")
south_sanfran_activities = pd.read_csv("data/south_sanfrancisco_activities.csv")
newyork_activities = pd.read_csv("data/newyork_activities.csv")
london_activities = pd.read_csv("data/london_activities.csv")

# %% [markdown]
# **Coordinates**
#
# These are the coordinates of a specific company within each city that was surrounded by the other companies.

# %%
sanfran_coord = [37.781929, -122.404176]
south_sanfran_coord = [37.656246, -122.399735]
newyork_coord = [40.739930, -73.993049]
london_coord = [51.514165, -0.109017]

# %% [markdown]
# ---

# %% [markdown]
# # Defining functions

# %% [markdown]
# **Function to create a map centered on given coordinates (the company)**

# %%
def createMap(coordinates):
    '''This function receives a list of coodinates in the format [latitude, longitude]
    and creates a map around it, marking your coordinates.
    '''
    # Creating the map
    mapa = Map(location = coordinates, zoom_start = 14, control_scale = True)
    # Creating my icon properties
    my_icon = Icon(color = "black", prefix = "fa", icon = "diamond")
    # Creating and adding my marker
    my_company = Marker(location = coordinates, tooltip = "EpicNice", icon = my_icon)
    my_company.add_to(mapa)
    
    return mapa

# %% [markdown]
# **Function to add the markers to the map**

# %%
def addMarkers(df, mapa):
    '''This function adds markers to your map.
    :df: the dataframe from which it takes the coordinates.
    :mapa: your map.
    '''
    for index, row in df.iterrows():

        # Add points coordinates (marker without the icon)
        query = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}

        # Add icons
        if row["query"] == "school":        
            icon = Icon (color = "blue",
                         prefix = "fa", icon = "graduation-cap")        
        elif row["query"] == "club":
            icon = Icon (color = "red",
                         prefix = "fa", icon = "glass")       
        elif row["query"] == "starbucks":
            icon = Icon (color = "gray",
                         prefix = "fa", icon = "coffee")
        elif row["query"] == "airport":
            icon = Icon (color = "purple",
                         prefix = "fa", icon = "plane")            
        elif row["query"] == "vegan restaurant":
            icon = Icon (color = "green",
                         prefix = "fa", icon = "cutlery")            
        elif row["query"] == "basketball":
            icon = Icon (color = "orange",
                         prefix = "fa", icon = "futbol-o")            
        elif row["query"] == "dog hairdresser":
            icon = Icon (color = "lightgray",
                         prefix = "fa", icon = "paw")
        elif row["query"] == "companies nearby":
            icon = Icon (color = "lightred",
                         prefix = "fa", icon = "building")        

        # Add markers with respective icon
        new_marker = Marker(**query, icon = icon, radius = 2)
        new_marker.add_to(mapa)
        
    return mapa

# %% [markdown]
# **Function to add a HeatMap to the map**

# %%
def addHeatMap(df, column, featuregroup, mapa):
    '''This function creates a feature group and adds it to the map as a heatmap.
    :df: df, the original df.
    :column: str, the name of the column where to look for the group.
    :featuregroup: str, your subgroup.
    :mapa: map, the map you want the group to be added.
    '''
    # Define the feature group
    df_subset = df[df[column] == featuregroup]
    df_group = folium.FeatureGroup(name = f"{featuregroup}: {df_subset.shape[0]}")
    HeatMap(data = df[["lat", "lon"]], radius = 25, 
        gradient = {0.4: 'yellow', 0.65: 'orange', 1: 'red'}).add_to(df_group)
    df_group.add_to(mapa)
    
    # Add layer control
    folium.LayerControl(collapsed = False, position = "topleft").add_to(mapa)
    
    return mapa

# %% [markdown]
# # Building maps

# %% [markdown]
# ## San Francisco

# %%
map_sanfran = createMap(sanfran_coord)
map_sanfran_1 = addMarkers(sanfran_activities, map_sanfran)
map_sanfran_2 = addMarkers(sanfran_companies, map_sanfran_1)

# %%
map_sanfran_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b703d2b9d161241efab36a75fadf53d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b703d2b9d161241efab36a75fadf53d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b703d2b9d161241efab36a75fadf53d1 = L.map(
#                 &quot;map_b703d2b9d161241efab36a75fadf53d1&quot;,
#                 {
#                     center: [37.781929, -122.404176],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b703d2b9d161241efab36a75fadf53d1);
#
#
#
#
#
#             var tile_layer_238a978c0f3cfee1aa5657c82c2d0e1d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b703d2b9d161241efab36a75fadf53d1);
#
#
#             var marker_219b047cb6edca55c36233a6fc8a1035 = L.marker(
#                 [37.781929, -122.404176],
#                 {}
#             ).addTo(map_b703d2b9d161241efab36a75fadf53d1);
#
#
#             var icon_59fa48b67189b0fd1a42ffff539d3c2d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;diamond&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_219b047cb6edca55c36233a6fc8a1035.setIcon(icon_59fa48b67189b0fd1a42ffff539d3c2d);
#
#
#             marker_219b047cb6edca55c36233a6fc8a1035.bindTooltip(
#                 `&lt;div&gt;
#                      EpicNice
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2f26858082f076fa5f807c74d9a68906 = L.marker(
#                 [37.781815, -122.401127],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_b703d2b9d161241efab36a75fadf53d1);
#
#
#             var icon_23f2960c83bd97ef650cb27b72469b90 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2f26858082f076fa5f807c74d9a68906.setIcon(icon_23f2960c83bd97ef650cb27b72469b90);
#
#
#             marker_2f26858082f076fa5f807c74d9a68906.bindTooltip(
#                 `&lt;div&gt;
#                      AltSchool Yerba Buena
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_71f0192508fad1423216106acd3dca46 = L.marker(
#                 [37.78065, -122.400556],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_b703d2b9d161241efab36a75fadf53d1);
#
#
#             var icon_a3d7a6efdc09775881e53d6c0b2a2e73 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_71f0192508fad1423216106acd3dca46.setIcon(icon_a3d7a6efdc09775881e53d6c0b2a2e73);
#
#
#             marker_71f0192508fad1423216106acd3dca46.bindTooltip(
#                 `&lt;div&gt;
#                      San Francisco Unified School District
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_52bf0fd7814e63c1f09f174f5232e2f4 = L.marker(
#                 [37.786362, -122.405338],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_b703d2b9d161241efab36a75fadf53d1);
#
#
#             var icon_bf082090aa33f647d9f5957839c3356e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_52bf0fd7814e63c1f09f174f5232e2f4.setIcon(icon_bf082090aa33f647d9f5957839c3356e);
#
#
#             marker_52bf0fd7814e63c1f09f174f5232e2f4.bindTooltip(
#                 `&lt;div&gt;
#                      American College of Early Childhood Education
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_62a929665ef31d0a23b37744017230fc = L.marker(
#                 [37.777146, -122.406228],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_b703d2b9d161241efab36a75fadf53d1);
#
#
#             var icon_365e096fb4b0c9d11f7e821bc39384f4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot

# %%
map_sanfran_2.save('./images/sanfran_map.html')

# %% [markdown]
# **With HeatMap (not that good)**

# %%
# Re-initializing my map
map_sanfran_3 = createMap(sanfran_coord)
map_sanfran_3 = addMarkers(sanfran_activities, map_sanfran_3)
map_sanfran_3 = addHeatMap(sanfran_companies, "query", "companies nearby", map_sanfran_3)

# %%
map_sanfran_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5006ed7d95dbda8e3f925a6bce56a314 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5006ed7d95dbda8e3f925a6bce56a314&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5006ed7d95dbda8e3f925a6bce56a314 = L.map(
#                 &quot;map_5006ed7d95dbda8e3f925a6bce56a314&quot;,
#                 {
#                     center: [37.781929, -122.404176],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5006ed7d95dbda8e3f925a6bce56a314);
#
#
#
#
#
#             var tile_layer_573716006d6c2ed6a80b004b2b48f89d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5006ed7d95dbda8e3f925a6bce56a314);
#
#
#             var marker_3995f93c047c0dc23267c5b6bedb211b = L.marker(
#                 [37.781929, -122.404176],
#                 {}
#             ).addTo(map_5006ed7d95dbda8e3f925a6bce56a314);
#
#
#             var icon_9d0a42946cd229f4689f047228b5f91c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;diamond&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3995f93c047c0dc23267c5b6bedb211b.setIcon(icon_9d0a42946cd229f4689f047228b5f91c);
#
#
#             marker_3995f93c047c0dc23267c5b6bedb211b.bindTooltip(
#                 `&lt;div&gt;
#                      EpicNice
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7c60f5118212a5f6a79900a5e82f95a6 = L.marker(
#                 [37.781815, -122.401127],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5006ed7d95dbda8e3f925a6bce56a314);
#
#
#             var icon_42edf3e51181cd4154197aa73a777b49 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7c60f5118212a5f6a79900a5e82f95a6.setIcon(icon_42edf3e51181cd4154197aa73a777b49);
#
#
#             marker_7c60f5118212a5f6a79900a5e82f95a6.bindTooltip(
#                 `&lt;div&gt;
#                      AltSchool Yerba Buena
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_28c294213b640a8f3114a071b1c59d3d = L.marker(
#                 [37.78065, -122.400556],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5006ed7d95dbda8e3f925a6bce56a314);
#
#
#             var icon_fc5f715d8c683f512ca0411041d54dfb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_28c294213b640a8f3114a071b1c59d3d.setIcon(icon_fc5f715d8c683f512ca0411041d54dfb);
#
#
#             marker_28c294213b640a8f3114a071b1c59d3d.bindTooltip(
#                 `&lt;div&gt;
#                      San Francisco Unified School District
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1efd5ac25415d44786817e5ba3d3826f = L.marker(
#                 [37.786362, -122.405338],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5006ed7d95dbda8e3f925a6bce56a314);
#
#
#             var icon_e7c04a69e7c6cdb7534b2dbcf3cdf1ed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1efd5ac25415d44786817e5ba3d3826f.setIcon(icon_e7c04a69e7c6cdb7534b2dbcf3cdf1ed);
#
#
#             marker_1efd5ac25415d44786817e5ba3d3826f.bindTooltip(
#                 `&lt;div&gt;
#                      American College of Early Childhood Education
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7e5cb61523cdd4373e79c1fcc83e24d3 = L.marker(
#                 [37.777146, -122.406228],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5006ed7d95dbda8e3f925a6bce56a314);
#
#
#             var icon_5ffdccbe534cc6d44d41ee26a4a905f9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,

# %% [markdown]
# ## South San Francisco

# %%
map_sout_sanfran = createMap(south_sanfran_coord)
map_sout_sanfran_1 = addMarkers(south_sanfran_activities, map_sout_sanfran)
map_south_sanfran_2 = addMarkers(south_sanfran_companies, map_sout_sanfran_1)
map_south_sanfran_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec1ded5d5a23f03ef1a57f3d04c7cef9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec1ded5d5a23f03ef1a57f3d04c7cef9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ec1ded5d5a23f03ef1a57f3d04c7cef9 = L.map(
#                 &quot;map_ec1ded5d5a23f03ef1a57f3d04c7cef9&quot;,
#                 {
#                     center: [37.656246, -122.399735],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ec1ded5d5a23f03ef1a57f3d04c7cef9);
#
#
#
#
#
#             var tile_layer_5d3a5a40528f21fcc981fb578d6030f4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ec1ded5d5a23f03ef1a57f3d04c7cef9);
#
#
#             var marker_24ff1b18e026118e03323ef5b2afd8a1 = L.marker(
#                 [37.656246, -122.399735],
#                 {}
#             ).addTo(map_ec1ded5d5a23f03ef1a57f3d04c7cef9);
#
#
#             var icon_607080516bddf7dedd612431815b077e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;diamond&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_24ff1b18e026118e03323ef5b2afd8a1.setIcon(icon_607080516bddf7dedd612431815b077e);
#
#
#             marker_24ff1b18e026118e03323ef5b2afd8a1.bindTooltip(
#                 `&lt;div&gt;
#                      EpicNice
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_78a5c01ec0575f35aea81d2ea261d4dd = L.marker(
#                 [37.663471, -122.410062],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_ec1ded5d5a23f03ef1a57f3d04c7cef9);
#
#
#             var icon_beb0fc22f07a46f2beb5600124662fba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_78a5c01ec0575f35aea81d2ea261d4dd.setIcon(icon_beb0fc22f07a46f2beb5600124662fba);
#
#
#             marker_78a5c01ec0575f35aea81d2ea261d4dd.bindTooltip(
#                 `&lt;div&gt;
#                      Martin Elementary School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_534399c13c2d28601a7618b2b866112e = L.marker(
#                 [37.644996, -122.401457],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_ec1ded5d5a23f03ef1a57f3d04c7cef9);
#
#
#             var icon_be012fe1ec32f03bd061d2b177001dda = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_534399c13c2d28601a7618b2b866112e.setIcon(icon_be012fe1ec32f03bd061d2b177001dda);
#
#
#             marker_534399c13c2d28601a7618b2b866112e.bindTooltip(
#                 `&lt;div&gt;
#                      Academic Insight
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3e147de5ac479da3e9b3ae908aeec9d5 = L.marker(
#                 [37.657254, -122.41528],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_ec1ded5d5a23f03ef1a57f3d04c7cef9);
#
#
#             var icon_19b0c079f1344b8c20bfbb166ffd9ac4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3e147de5ac479da3e9b3ae908aeec9d5.setIcon(icon_19b0c079f1344b8c20bfbb166ffd9ac4);
#
#
#             marker_3e147de5ac479da3e9b3ae908aeec9d5.bindTooltip(
#                 `&lt;div&gt;
#                      All Souls Catholic School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bd9f1da86971f62c4fb16774d0f9d7ab = L.marker(
#                 [37.658973, -122.416312],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_ec1ded5d5a23f03ef1a57f3d04c7cef9);
#
#
#             var icon_6c2339e5ae0953242ae5338259f09c2d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );

# %%
map_south_sanfran_2.save('./images/south_sanfran_map.html')

# %% [markdown]
# ## New York

# %%
map_newyork = createMap(newyork_coord)
map_newyork_1 = addMarkers(newyork_activities, map_newyork)
map_newyork_2 = addMarkers(newyork_companies, map_newyork_1)
map_newyork_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c58018d1b151026786fd11b5dca8e64 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c58018d1b151026786fd11b5dca8e64&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2c58018d1b151026786fd11b5dca8e64 = L.map(
#                 &quot;map_2c58018d1b151026786fd11b5dca8e64&quot;,
#                 {
#                     center: [40.73993, -73.993049],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2c58018d1b151026786fd11b5dca8e64);
#
#
#
#
#
#             var tile_layer_9e7ecbbd9a352c39dd859e20fdcc19b6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c58018d1b151026786fd11b5dca8e64);
#
#
#             var marker_0de0e665ee52a41fb9e85964f7b06798 = L.marker(
#                 [40.73993, -73.993049],
#                 {}
#             ).addTo(map_2c58018d1b151026786fd11b5dca8e64);
#
#
#             var icon_42564b28734ca6728b1ea7ab384afa15 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;diamond&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0de0e665ee52a41fb9e85964f7b06798.setIcon(icon_42564b28734ca6728b1ea7ab384afa15);
#
#
#             marker_0de0e665ee52a41fb9e85964f7b06798.bindTooltip(
#                 `&lt;div&gt;
#                      EpicNice
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_66aded58ab033690e2f4b54fd13ea841 = L.marker(
#                 [40.740084, -73.99246],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_2c58018d1b151026786fd11b5dca8e64);
#
#
#             var icon_279cc96579ee3f6ebe50ba62e0016eff = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_66aded58ab033690e2f4b54fd13ea841.setIcon(icon_279cc96579ee3f6ebe50ba62e0016eff);
#
#
#             marker_66aded58ab033690e2f4b54fd13ea841.bindTooltip(
#                 `&lt;div&gt;
#                      Holocaust Education Foundation
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fe7a8c89fad419b22dcb27d796e7c152 = L.marker(
#                 [40.738875, -73.993286],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_2c58018d1b151026786fd11b5dca8e64);
#
#
#             var icon_50934b9f653cdbb207a696d36d8dea91 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fe7a8c89fad419b22dcb27d796e7c152.setIcon(icon_50934b9f653cdbb207a696d36d8dea91);
#
#
#             marker_fe7a8c89fad419b22dcb27d796e7c152.bindTooltip(
#                 `&lt;div&gt;
#                      Victory Schools
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f6e388703d08483b0f33c91ca78b742b = L.marker(
#                 [40.739036, -73.995301],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_2c58018d1b151026786fd11b5dca8e64);
#
#
#             var icon_5c81b41e6b5c4c3a1d21c4c602ee9422 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f6e388703d08483b0f33c91ca78b742b.setIcon(icon_5c81b41e6b5c4c3a1d21c4c602ee9422);
#
#
#             marker_f6e388703d08483b0f33c91ca78b742b.bindTooltip(
#                 `&lt;div&gt;
#                      Ps 340
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3492c30e397550edfe61e11416d52d99 = L.marker(
#                 [40.737837, -73.991761],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_2c58018d1b151026786fd11b5dca8e64);
#
#
#             var icon_126606127f089d0fb8becfd807cef76a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3492c30

# %%
map_newyork_2.save('./images/newyork_map.html')

# %% [markdown]
# ## London (GBR)

# %%
map_london = createMap(london_coord)
map_london_1 = addMarkers(london_activities, map_london)
map_london_2 = addMarkers(london_companies, map_london_1)
map_london_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4df2d6ba1083e10b7caac05460732233 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4df2d6ba1083e10b7caac05460732233&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4df2d6ba1083e10b7caac05460732233 = L.map(
#                 &quot;map_4df2d6ba1083e10b7caac05460732233&quot;,
#                 {
#                     center: [51.514165, -0.109017],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4df2d6ba1083e10b7caac05460732233);
#
#
#
#
#
#             var tile_layer_9a748e9e721f22586bd11c56fcf1bcab = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4df2d6ba1083e10b7caac05460732233);
#
#
#             var marker_973d385e44df9c10f4415433acb47ff7 = L.marker(
#                 [51.514165, -0.109017],
#                 {}
#             ).addTo(map_4df2d6ba1083e10b7caac05460732233);
#
#
#             var icon_0564478a8cc2365800b70082be93e66f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;diamond&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_973d385e44df9c10f4415433acb47ff7.setIcon(icon_0564478a8cc2365800b70082be93e66f);
#
#
#             marker_973d385e44df9c10f4415433acb47ff7.bindTooltip(
#                 `&lt;div&gt;
#                      EpicNice
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a06b79a3d9cb9c76b62617471d231829 = L.marker(
#                 [51.520223, -0.110579],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_4df2d6ba1083e10b7caac05460732233);
#
#
#             var icon_ff85dc6f4e326486e69ab049cc98c039 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a06b79a3d9cb9c76b62617471d231829.setIcon(icon_ff85dc6f4e326486e69ab049cc98c039);
#
#
#             marker_a06b79a3d9cb9c76b62617471d231829.bindTooltip(
#                 `&lt;div&gt;
#                      St Albans Primary School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f0e1a22ad4fb478d6b788f8db741c7e4 = L.marker(
#                 [51.513546, -0.119311],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_4df2d6ba1083e10b7caac05460732233);
#
#
#             var icon_02cfdf91b8fa4e63dc74d252c836aa3a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f0e1a22ad4fb478d6b788f8db741c7e4.setIcon(icon_02cfdf91b8fa4e63dc74d252c836aa3a);
#
#
#             marker_f0e1a22ad4fb478d6b788f8db741c7e4.bindTooltip(
#                 `&lt;div&gt;
#                      St Clement Danes C of E Primary School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b82139596c711ab803fd47c3739cc57a = L.marker(
#                 [51.516073, -0.121987],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_4df2d6ba1083e10b7caac05460732233);
#
#
#             var icon_2ad10446fb4ac4beceb915415838ca07 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b82139596c711ab803fd47c3739cc57a.setIcon(icon_2ad10446fb4ac4beceb915415838ca07);
#
#
#             marker_b82139596c711ab803fd47c3739cc57a.bindTooltip(
#                 `&lt;div&gt;
#                      St Josephs R C Primary School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9d7e93d0583076d872109c7e191e78d3 = L.marker(
#                 [51.522687, -0.112286],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_4df2d6ba1083e10b7caac05460732233);
#
#
#             var icon_2bf1cb1b562d3e296cb70bf6ac1f336b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}

# %%
map_london_2.save('./images/london_map.html')
