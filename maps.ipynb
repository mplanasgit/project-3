# %% [markdown]
# **Maps of activities near my company on each city**
#
# ---

# %% [markdown]
# **Libraries**

# %%
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd

# %% [markdown]
# **Coordinates**

# %%
sanfran_coord = [37.781929, -122.404176]
south_sanfran_coord = [37.656246, -122.399735]
newyork_coord = [40.739930, -73.993049]
london_coord = [51.514165, -0.109017]

# %% [markdown]
# **Datasets**

# %%
# Companies:
sanfran_companies = pd.read_csv('./data/companies_sanfrancisco_map.csv')
south_sanfran_companies = pd.read_csv('./data/companies_south_sanfrancisco_map.csv')
newyork_companies = pd.read_csv('./data/companies_newyork_map.csv')
london_companies = pd.read_csv('./data/companies_london_map.csv')

# %%
# Activities/Categories:
sanfran_activities = pd.read_csv("data/sanfrancisco_activities.csv")
south_sanfran_activities = pd.read_csv("data/south_sanfrancisco_activities.csv")
newyork_activities = pd.read_csv("data/newyork_activities.csv")
london_activities = pd.read_csv("data/london_activities.csv")

# %% [markdown]
# ---

# %% [markdown]
# **Function to create a map around the company**

# %%
def createMap(coordinates):
    '''This function receives a list of coodinates in the format [latitude, longitude]
    and creates a map around it, marking your coordinates.
    '''
    # Creating the map
    mapa = Map(location = coordinates, zoom_start = 14, control_scale = True)
    # Creating my icon properties
    my_icon = Icon(color = "black", prefix = "fa", icon = "diamond")
    # Creating and adding my marker
    my_company = Marker(location = coordinates, tooltip = "EpicNice", icon = my_icon)
    my_company.add_to(mapa)
    
    return mapa

# %% [markdown]
# **Function to add the markers to the map**

# %%
def addMarkers(df, mapa):
    '''This function adds markers to your map.
    :df: the dataframe from which it takes the coordinates.
    :mapa: your map.
    '''
    for index, row in df.iterrows():

        # Add points coordinates (marker without the icon)
        query = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}

        # Add icons
        if row["query"] == "school":        
            icon = Icon (color = "blue",
                         prefix = "fa", icon = "graduation-cap")        
        elif row["query"] == "club":
            icon = Icon (color = "red",
                         prefix = "fa", icon = "glass")       
        elif row["query"] == "starbucks":
            icon = Icon (color = "gray",
                         prefix = "fa", icon = "coffee")
        elif row["query"] == "airport":
            icon = Icon (color = "purple",
                         prefix = "fa", icon = "plane")            
        elif row["query"] == "vegan restaurant":
            icon = Icon (color = "green",
                         prefix = "fa", icon = "cutlery")            
        elif row["query"] == "basketball":
            icon = Icon (color = "orange",
                         prefix = "fa", icon = "futbol-o")            
        elif row["query"] == "dog hairdresser":
            icon = Icon (color = "lightgray",
                         prefix = "fa", icon = "paw")
        elif row["query"] == "companies nearby":
            icon = Icon (color = "lightred",
                         prefix = "fa", icon = "building")        

        # Add markers with respective icon
        new_marker = Marker(**query, icon = icon, radius = 2)
        new_marker.add_to(mapa)
        
    return mapa

# %% [markdown]
# **Function to add HeatMap**

# %%
def addHeatMap(df, column, featuregroup, mapa):
    '''This function creates a feature group and adds it to the map as a heatmap.
    :df: df, the original df.
    :column: str, the name of the column where to look for the group.
    :featuregroup: str, your subgroup.
    :mapa: map, the map you want the group to be added.
    '''
    # Define the feature group
    df_subset = df[df[column] == featuregroup]
    df_group = folium.FeatureGroup(name = f"{featuregroup}: {df_subset.shape[0]}")
    HeatMap(data = df[["lat", "lon"]], radius = 25, 
        gradient = {0.4: 'yellow', 0.65: 'orange', 1: 'red'}).add_to(df_group)
    df_group.add_to(mapa)
    
    # Add layer control
    folium.LayerControl(collapsed = False, position = "topleft").add_to(mapa)
    
    return mapa

# %% [markdown]
# # San Francisco

# %%
map_sanfran = createMap(sanfran_coord)
map_sanfran_1 = addMarkers(sanfran_activities, map_sanfran)
map_sanfran_2 = addMarkers(sanfran_companies, map_sanfran_1)

# %%
map_sanfran_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c54fdbbec8ad5a3e5e79198be4e072cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c54fdbbec8ad5a3e5e79198be4e072cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c54fdbbec8ad5a3e5e79198be4e072cf = L.map(
#                 &quot;map_c54fdbbec8ad5a3e5e79198be4e072cf&quot;,
#                 {
#                     center: [37.781929, -122.404176],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c54fdbbec8ad5a3e5e79198be4e072cf);
#
#
#
#
#
#             var tile_layer_a08bd8e39b529925211077a060bc56d8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c54fdbbec8ad5a3e5e79198be4e072cf);
#
#
#             var marker_89663bdf27c036338c494f1dae204000 = L.marker(
#                 [37.781929, -122.404176],
#                 {}
#             ).addTo(map_c54fdbbec8ad5a3e5e79198be4e072cf);
#
#
#             var icon_155c501efb13d7f2c25321ce8b56f1b5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;diamond&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_89663bdf27c036338c494f1dae204000.setIcon(icon_155c501efb13d7f2c25321ce8b56f1b5);
#
#
#             marker_89663bdf27c036338c494f1dae204000.bindTooltip(
#                 `&lt;div&gt;
#                      EpicNice
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e1ce6ab7bd24884bd1d2dc542e8a2040 = L.marker(
#                 [37.781815, -122.401127],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_c54fdbbec8ad5a3e5e79198be4e072cf);
#
#
#             var icon_480b42ea69c2d8eabff58868d2fc2e96 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e1ce6ab7bd24884bd1d2dc542e8a2040.setIcon(icon_480b42ea69c2d8eabff58868d2fc2e96);
#
#
#             marker_e1ce6ab7bd24884bd1d2dc542e8a2040.bindTooltip(
#                 `&lt;div&gt;
#                      AltSchool Yerba Buena
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f51d003157e57f8304211667f832d1e7 = L.marker(
#                 [37.78065, -122.400556],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_c54fdbbec8ad5a3e5e79198be4e072cf);
#
#
#             var icon_8547a40532648310731ae48639f25bb6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f51d003157e57f8304211667f832d1e7.setIcon(icon_8547a40532648310731ae48639f25bb6);
#
#
#             marker_f51d003157e57f8304211667f832d1e7.bindTooltip(
#                 `&lt;div&gt;
#                      San Francisco Unified School District
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_289886df3ec450161409639cd6470e97 = L.marker(
#                 [37.786362, -122.405338],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_c54fdbbec8ad5a3e5e79198be4e072cf);
#
#
#             var icon_cb2436b20bfae821a33fc5507c6ae1c4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_289886df3ec450161409639cd6470e97.setIcon(icon_cb2436b20bfae821a33fc5507c6ae1c4);
#
#
#             marker_289886df3ec450161409639cd6470e97.bindTooltip(
#                 `&lt;div&gt;
#                      American College of Early Childhood Education
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0150dddc5699703354cff0297dc10319 = L.marker(
#                 [37.777146, -122.406228],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_c54fdbbec8ad5a3e5e79198be4e072cf);
#
#
#             var icon_4bd10b9209033e569613f27b12047f4d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot

# %%
map_sanfran_2.save('./images/sanfran_map.html')

# %% [markdown]
# **With HeatMap (not that good)**

# %%
# Re-initializing my map
map_sanfran_3 = createMap(sanfran_coord)
map_sanfran_3 = addMarkers(sanfran_activities, map_sanfran_3)
map_sanfran_3 = addHeatMap(sanfran_companies, "query", "companies nearby", map_sanfran_3)

# %%
map_sanfran_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98f00af998ae9ebb6f6e726a80af402c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98f00af998ae9ebb6f6e726a80af402c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_98f00af998ae9ebb6f6e726a80af402c = L.map(
#                 &quot;map_98f00af998ae9ebb6f6e726a80af402c&quot;,
#                 {
#                     center: [37.781929, -122.404176],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_98f00af998ae9ebb6f6e726a80af402c);
#
#
#
#
#
#             var tile_layer_306b85178cb316abb267bb777cc6345f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_98f00af998ae9ebb6f6e726a80af402c);
#
#
#             var marker_ae1e77302e45b01123f31356fb4fe787 = L.marker(
#                 [37.781929, -122.404176],
#                 {}
#             ).addTo(map_98f00af998ae9ebb6f6e726a80af402c);
#
#
#             var icon_f298b0f1b5106dd7db43e9bcef69ca85 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;diamond&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ae1e77302e45b01123f31356fb4fe787.setIcon(icon_f298b0f1b5106dd7db43e9bcef69ca85);
#
#
#             marker_ae1e77302e45b01123f31356fb4fe787.bindTooltip(
#                 `&lt;div&gt;
#                      EpicNice
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fc19ef6ec5a3d8deddbabb8e71ffb10b = L.marker(
#                 [37.781815, -122.401127],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_98f00af998ae9ebb6f6e726a80af402c);
#
#
#             var icon_097944b369605c2374986bbbd784554b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fc19ef6ec5a3d8deddbabb8e71ffb10b.setIcon(icon_097944b369605c2374986bbbd784554b);
#
#
#             marker_fc19ef6ec5a3d8deddbabb8e71ffb10b.bindTooltip(
#                 `&lt;div&gt;
#                      AltSchool Yerba Buena
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7c4b460a10081f0930550b80a67d836c = L.marker(
#                 [37.78065, -122.400556],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_98f00af998ae9ebb6f6e726a80af402c);
#
#
#             var icon_02bfbd3dc36a8a082ac4df52f583dc0b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7c4b460a10081f0930550b80a67d836c.setIcon(icon_02bfbd3dc36a8a082ac4df52f583dc0b);
#
#
#             marker_7c4b460a10081f0930550b80a67d836c.bindTooltip(
#                 `&lt;div&gt;
#                      San Francisco Unified School District
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a022cf7d79f0509f013587f77dad1bfb = L.marker(
#                 [37.786362, -122.405338],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_98f00af998ae9ebb6f6e726a80af402c);
#
#
#             var icon_ef4b568a01bc38f5ae1b80983125bfe2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a022cf7d79f0509f013587f77dad1bfb.setIcon(icon_ef4b568a01bc38f5ae1b80983125bfe2);
#
#
#             marker_a022cf7d79f0509f013587f77dad1bfb.bindTooltip(
#                 `&lt;div&gt;
#                      American College of Early Childhood Education
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4512ee9543fbdcfccc04b3ac85fd3f6c = L.marker(
#                 [37.777146, -122.406228],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_98f00af998ae9ebb6f6e726a80af402c);
#
#
#             var icon_77fde5c5429a0a2352b59b31f17bf2b5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,

# %% [markdown]
# # South San Francisco

# %%
map_sout_sanfran = createMap(south_sanfran_coord)
map_sout_sanfran_1 = addMarkers(south_sanfran_activities, map_sout_sanfran)
map_south_sanfran_2 = addMarkers(south_sanfran_companies, map_sout_sanfran_1)
map_south_sanfran_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f383dceb0031ae6d6274d69794bdb290 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f383dceb0031ae6d6274d69794bdb290&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f383dceb0031ae6d6274d69794bdb290 = L.map(
#                 &quot;map_f383dceb0031ae6d6274d69794bdb290&quot;,
#                 {
#                     center: [37.656246, -122.399735],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f383dceb0031ae6d6274d69794bdb290);
#
#
#
#
#
#             var tile_layer_441f37b05d44bacb44388c1e22bea095 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f383dceb0031ae6d6274d69794bdb290);
#
#
#             var marker_a44e72318d8bd66b549195a3ee293206 = L.marker(
#                 [37.656246, -122.399735],
#                 {}
#             ).addTo(map_f383dceb0031ae6d6274d69794bdb290);
#
#
#             var icon_4d4f6ad62aed7c9db0bc582b63667434 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;diamond&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a44e72318d8bd66b549195a3ee293206.setIcon(icon_4d4f6ad62aed7c9db0bc582b63667434);
#
#
#             marker_a44e72318d8bd66b549195a3ee293206.bindTooltip(
#                 `&lt;div&gt;
#                      EpicNice
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_98f87b68082edfca79be225a5e93675a = L.marker(
#                 [37.663471, -122.410062],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_f383dceb0031ae6d6274d69794bdb290);
#
#
#             var icon_03438adae9ac2969b0cce0df071102e4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_98f87b68082edfca79be225a5e93675a.setIcon(icon_03438adae9ac2969b0cce0df071102e4);
#
#
#             marker_98f87b68082edfca79be225a5e93675a.bindTooltip(
#                 `&lt;div&gt;
#                      Martin Elementary School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8028406ce740fb70559d312ed180725a = L.marker(
#                 [37.644996, -122.401457],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_f383dceb0031ae6d6274d69794bdb290);
#
#
#             var icon_d2770f80fb63af0647deed3b5920de09 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8028406ce740fb70559d312ed180725a.setIcon(icon_d2770f80fb63af0647deed3b5920de09);
#
#
#             marker_8028406ce740fb70559d312ed180725a.bindTooltip(
#                 `&lt;div&gt;
#                      Academic Insight
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_caee694b8de64abd76bf5a3ce6334ba8 = L.marker(
#                 [37.657254, -122.41528],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_f383dceb0031ae6d6274d69794bdb290);
#
#
#             var icon_d0ad39eca7f5313b50a7051bb0f535c9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_caee694b8de64abd76bf5a3ce6334ba8.setIcon(icon_d0ad39eca7f5313b50a7051bb0f535c9);
#
#
#             marker_caee694b8de64abd76bf5a3ce6334ba8.bindTooltip(
#                 `&lt;div&gt;
#                      All Souls Catholic School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9156d9a030e54963adc5196324644bb6 = L.marker(
#                 [37.658973, -122.416312],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_f383dceb0031ae6d6274d69794bdb290);
#
#
#             var icon_30000df7307419cd22f9317733b36b8e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );

# %%
map_south_sanfran_2.save('./images/south_sanfran_map.html')

# %% [markdown]
# # New York

# %%
map_newyork = createMap(newyork_coord)
map_newyork_1 = addMarkers(newyork_activities, map_newyork)
map_newyork_2 = addMarkers(newyork_companies, map_newyork_1)
map_newyork_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_247a7f73d33d90132412e8a7d6503348 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_247a7f73d33d90132412e8a7d6503348&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_247a7f73d33d90132412e8a7d6503348 = L.map(
#                 &quot;map_247a7f73d33d90132412e8a7d6503348&quot;,
#                 {
#                     center: [40.73993, -73.993049],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_247a7f73d33d90132412e8a7d6503348);
#
#
#
#
#
#             var tile_layer_1ec815195b02f79994f25dc706163d72 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_247a7f73d33d90132412e8a7d6503348);
#
#
#             var marker_d7961cd91f6164b2cc7cceb84e378dd6 = L.marker(
#                 [40.73993, -73.993049],
#                 {}
#             ).addTo(map_247a7f73d33d90132412e8a7d6503348);
#
#
#             var icon_ef2c00835ffb7360840aefe8f7ea23db = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;diamond&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d7961cd91f6164b2cc7cceb84e378dd6.setIcon(icon_ef2c00835ffb7360840aefe8f7ea23db);
#
#
#             marker_d7961cd91f6164b2cc7cceb84e378dd6.bindTooltip(
#                 `&lt;div&gt;
#                      EpicNice
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bac453ecb087b9741fe1be3100176c0b = L.marker(
#                 [40.740084, -73.99246],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_247a7f73d33d90132412e8a7d6503348);
#
#
#             var icon_adc5755367cafcbe9ffa0b66df670fa5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bac453ecb087b9741fe1be3100176c0b.setIcon(icon_adc5755367cafcbe9ffa0b66df670fa5);
#
#
#             marker_bac453ecb087b9741fe1be3100176c0b.bindTooltip(
#                 `&lt;div&gt;
#                      Holocaust Education Foundation
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5beb1d4bc51405e4caa10c1baa2ea389 = L.marker(
#                 [40.738875, -73.993286],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_247a7f73d33d90132412e8a7d6503348);
#
#
#             var icon_d145299085621d959227ca149e50f0b1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5beb1d4bc51405e4caa10c1baa2ea389.setIcon(icon_d145299085621d959227ca149e50f0b1);
#
#
#             marker_5beb1d4bc51405e4caa10c1baa2ea389.bindTooltip(
#                 `&lt;div&gt;
#                      Victory Schools
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f7cc9035149ceb2f961631d699ad2231 = L.marker(
#                 [40.739036, -73.995301],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_247a7f73d33d90132412e8a7d6503348);
#
#
#             var icon_8d54238247282412c3925945296e6a18 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f7cc9035149ceb2f961631d699ad2231.setIcon(icon_8d54238247282412c3925945296e6a18);
#
#
#             marker_f7cc9035149ceb2f961631d699ad2231.bindTooltip(
#                 `&lt;div&gt;
#                      Ps 340
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c1d34306f92b750aeb9451c97beff538 = L.marker(
#                 [40.737837, -73.991761],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_247a7f73d33d90132412e8a7d6503348);
#
#
#             var icon_619b7d5385a9d8236aae3a28ece87912 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c1d3430

# %%
map_newyork_2.save('./images/newyork_map.html')

# %% [markdown]
# # London

# %%
map_london = createMap(london_coord)
map_london_1 = addMarkers(london_activities, map_london)
map_london_2 = addMarkers(london_companies, map_london_1)
map_london_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7cd17de4311020e6b51d255943252ead {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7cd17de4311020e6b51d255943252ead&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7cd17de4311020e6b51d255943252ead = L.map(
#                 &quot;map_7cd17de4311020e6b51d255943252ead&quot;,
#                 {
#                     center: [51.514165, -0.109017],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7cd17de4311020e6b51d255943252ead);
#
#
#
#
#
#             var tile_layer_bfba5423678f891f63bf09d38cd25350 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7cd17de4311020e6b51d255943252ead);
#
#
#             var marker_9678cc3bf2f255afe7b11ab2ef1ba8af = L.marker(
#                 [51.514165, -0.109017],
#                 {}
#             ).addTo(map_7cd17de4311020e6b51d255943252ead);
#
#
#             var icon_4c09b5324620259156c89b89a2bfc014 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;diamond&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9678cc3bf2f255afe7b11ab2ef1ba8af.setIcon(icon_4c09b5324620259156c89b89a2bfc014);
#
#
#             marker_9678cc3bf2f255afe7b11ab2ef1ba8af.bindTooltip(
#                 `&lt;div&gt;
#                      EpicNice
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7616691d3dbfb4a80ace27eb36d90d5d = L.marker(
#                 [51.520223, -0.110579],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_7cd17de4311020e6b51d255943252ead);
#
#
#             var icon_a08c89c4a5a5e78d49e1da2fc1a93db6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7616691d3dbfb4a80ace27eb36d90d5d.setIcon(icon_a08c89c4a5a5e78d49e1da2fc1a93db6);
#
#
#             marker_7616691d3dbfb4a80ace27eb36d90d5d.bindTooltip(
#                 `&lt;div&gt;
#                      St Albans Primary School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8ff85746c30596df284609536bbd74ee = L.marker(
#                 [51.513546, -0.119311],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_7cd17de4311020e6b51d255943252ead);
#
#
#             var icon_933f7640778483ddc4269dd352d9f869 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8ff85746c30596df284609536bbd74ee.setIcon(icon_933f7640778483ddc4269dd352d9f869);
#
#
#             marker_8ff85746c30596df284609536bbd74ee.bindTooltip(
#                 `&lt;div&gt;
#                      St Clement Danes C of E Primary School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9d95c5d8fcedbe40fda56a5e4ae40cd8 = L.marker(
#                 [51.516073, -0.121987],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_7cd17de4311020e6b51d255943252ead);
#
#
#             var icon_da921e2492173bd78b87b1ba2ed3faba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9d95c5d8fcedbe40fda56a5e4ae40cd8.setIcon(icon_da921e2492173bd78b87b1ba2ed3faba);
#
#
#             marker_9d95c5d8fcedbe40fda56a5e4ae40cd8.bindTooltip(
#                 `&lt;div&gt;
#                      St Josephs R C Primary School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_899fb133309612db6ebab00d46c00490 = L.marker(
#                 [51.522687, -0.112286],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_7cd17de4311020e6b51d255943252ead);
#
#
#             var icon_8aa7eef01a7b79a92aca2b496d6bb2e6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}

# %%
map_london_2.save('./images/london_map.html')
