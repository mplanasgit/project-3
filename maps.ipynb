# %% [markdown]
# **Maps of activities near my company on each city**
#
# ---

# %% [markdown]
# **Libraries**

# %%
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd

# %% [markdown]
# **Coordinates**

# %%
sanfran_coord = [37.781929, -122.404176]
south_sanfran_coord = [37.656246, -122.399735]
newyork_coord = [40.739930, -73.993049]
london_coord = [51.514165, -0.109017]

# %% [markdown]
# **Datasets**

# %%
# Companies:
sanfran_companies = pd.read_csv('./data/companies_sanfrancisco_map.csv')
south_sanfran_companies = pd.read_csv('./data/companies_south_sanfrancisco_map.csv')
newyork_companies = pd.read_csv('./data/companies_newyork_map.csv')
london_companies = pd.read_csv('./data/companies_london_map.csv')

# %%
# Activities/Categories:
sanfran_activities = pd.read_csv("data/sanfrancisco_activities.csv")
south_sanfran_activities = pd.read_csv("data/south_sanfrancisco_activities.csv")
newyork_activities = pd.read_csv("data/newyork_activities.csv")
london_activities = pd.read_csv("data/london_activities.csv")

# %% [markdown]
# ---

# %% [markdown]
# **Function to create a map around the company**

# %%
def createMap(coordinates):
    '''This function receives a list of coodinates in the format [latitude, longitude]
    and creates a map around it, marking your coordinates.
    '''
    # Creating the map
    mapa = Map(location = coordinates, zoom_start = 14, control_scale = True)
    # Creating my icon properties
    my_icon = Icon(color = "black", prefix = "fa", icon = "diamond")
    # Creating and adding my marker
    my_company = Marker(location = coordinates, tooltip = "EpicNice", icon = my_icon)
    my_company.add_to(mapa)
    
    return mapa

# %% [markdown]
# **Function to add the markers to the map**

# %%
def addMarkers(df, mapa):
    '''This function adds markers to your map.
    :df: the dataframe from which it takes the coordinates.
    :mapa: your map.
    '''
    for index, row in df.iterrows():

        # Add points coordinates (marker without the icon)
        query = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}

        # Add icons
        if row["query"] == "school":        
            icon = Icon (color = "blue",
                         prefix = "fa", icon = "graduation-cap")        
        elif row["query"] == "club":
            icon = Icon (color = "red",
                         prefix = "fa", icon = "glass")       
        elif row["query"] == "starbucks":
            icon = Icon (color = "gray",
                         prefix = "fa", icon = "coffee")
        elif row["query"] == "airport":
            icon = Icon (color = "purple",
                         prefix = "fa", icon = "plane")            
        elif row["query"] == "vegan restaurant":
            icon = Icon (color = "green",
                         prefix = "fa", icon = "cutlery")            
        elif row["query"] == "basketball":
            icon = Icon (color = "orange",
                         prefix = "fa", icon = "futbol-o")            
        elif row["query"] == "dog hairdresser":
            icon = Icon (color = "lightgray",
                         prefix = "fa", icon = "paw")
        elif row["query"] == "companies nearby":
            icon = Icon (color = "lightred",
                         prefix = "fa", icon = "building")        

        # Add markers with respective icon
        new_marker = Marker(**query, icon = icon, radius = 2)
        new_marker.add_to(mapa)
        
    return mapa

# %% [markdown]
# **Function to add HeatMap**

# %%
def addHeatMap(df, column, featuregroup, mapa):
    '''This function creates a feature group and adds it to the map as a heatmap.
    :df: df, the original df.
    :column: str, the name of the column where to look for the group.
    :featuregroup: str, your subgroup.
    :mapa: map, the map you want the group to be added.
    '''
    # Define the feature group
    df_subset = df[df[column] == featuregroup]
    df_group = folium.FeatureGroup(name = f"{featuregroup}: {df_subset.shape[0]}")
    HeatMap(data = df[["lat", "lon"]], radius = 25, 
        gradient = {0.4: 'yellow', 0.65: 'orange', 1: 'red'}).add_to(df_group)
    df_group.add_to(mapa)
    
    # Add layer control
    folium.LayerControl(collapsed = False, position = "topleft").add_to(mapa)
    
    return mapa

# %% [markdown]
# # San Francisco

# %%
map_sanfran = createMap(sanfran_coord)
map_sanfran_1 = addMarkers(sanfran_activities, map_sanfran)
map_sanfran_2 = addMarkers(sanfran_companies, map_sanfran_1)

# %%
map_sanfran_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0623c39b79f8e5db3cc937fd4fea2556 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0623c39b79f8e5db3cc937fd4fea2556&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0623c39b79f8e5db3cc937fd4fea2556 = L.map(
#                 &quot;map_0623c39b79f8e5db3cc937fd4fea2556&quot;,
#                 {
#                     center: [37.781929, -122.404176],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0623c39b79f8e5db3cc937fd4fea2556);
#
#
#
#
#
#             var tile_layer_969babd545dbcf420ca25b55a3cae2c0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0623c39b79f8e5db3cc937fd4fea2556);
#
#
#             var marker_610bc84cee3a614b3fa531c52e122ca3 = L.marker(
#                 [37.781929, -122.404176],
#                 {}
#             ).addTo(map_0623c39b79f8e5db3cc937fd4fea2556);
#
#
#             var icon_c725165e5ccae48bc1cb2f211c2294ea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;diamond&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_610bc84cee3a614b3fa531c52e122ca3.setIcon(icon_c725165e5ccae48bc1cb2f211c2294ea);
#
#
#             marker_610bc84cee3a614b3fa531c52e122ca3.bindTooltip(
#                 `&lt;div&gt;
#                      EpicNice
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_735f0343892cb0b8547686f39347fa68 = L.marker(
#                 [37.781815, -122.401127],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_0623c39b79f8e5db3cc937fd4fea2556);
#
#
#             var icon_be45375f029e9645f3eaf6bface1da2f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_735f0343892cb0b8547686f39347fa68.setIcon(icon_be45375f029e9645f3eaf6bface1da2f);
#
#
#             marker_735f0343892cb0b8547686f39347fa68.bindTooltip(
#                 `&lt;div&gt;
#                      AltSchool Yerba Buena
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7f2e628e4dadd7d6ff2c3b473e95f91f = L.marker(
#                 [37.78065, -122.400556],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_0623c39b79f8e5db3cc937fd4fea2556);
#
#
#             var icon_630ece5e0bd2908aaa27fe54eace7ccf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7f2e628e4dadd7d6ff2c3b473e95f91f.setIcon(icon_630ece5e0bd2908aaa27fe54eace7ccf);
#
#
#             marker_7f2e628e4dadd7d6ff2c3b473e95f91f.bindTooltip(
#                 `&lt;div&gt;
#                      San Francisco Unified School District
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b782a1e62224c605f3af4ed2d5099b2c = L.marker(
#                 [37.786362, -122.405338],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_0623c39b79f8e5db3cc937fd4fea2556);
#
#
#             var icon_3e77fb72c851aa96c2aed831a493a4d8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b782a1e62224c605f3af4ed2d5099b2c.setIcon(icon_3e77fb72c851aa96c2aed831a493a4d8);
#
#
#             marker_b782a1e62224c605f3af4ed2d5099b2c.bindTooltip(
#                 `&lt;div&gt;
#                      American College of Early Childhood Education
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6f68d4b41e615ecea188af34802fcf17 = L.marker(
#                 [37.777146, -122.406228],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_0623c39b79f8e5db3cc937fd4fea2556);
#
#
#             var icon_a58fbaec64e36a9c02a710ab5bed4e9b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot

# %%
map_sanfran_2.save('./images/sanfran_map.html')

# %% [markdown]
# **With HeatMap (not that good)**

# %%
# Re-initializing my map
map_sanfran_3 = createMap(sanfran_coord)
map_sanfran_3 = addMarkers(sanfran_activities, map_sanfran_3)
map_sanfran_3 = addHeatMap(sanfran_companies, "query", "companies nearby", map_sanfran_3)

# %%
map_sanfran_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08d4f1ff39673f38d849ac0a62f0517d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08d4f1ff39673f38d849ac0a62f0517d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_08d4f1ff39673f38d849ac0a62f0517d = L.map(
#                 &quot;map_08d4f1ff39673f38d849ac0a62f0517d&quot;,
#                 {
#                     center: [37.781929, -122.404176],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_08d4f1ff39673f38d849ac0a62f0517d);
#
#
#
#
#
#             var tile_layer_44331f81b7ce63dcbc11e9c25cbf7983 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_08d4f1ff39673f38d849ac0a62f0517d);
#
#
#             var marker_e56f4bb5f9780ec63dbecc63c52908aa = L.marker(
#                 [37.781929, -122.404176],
#                 {}
#             ).addTo(map_08d4f1ff39673f38d849ac0a62f0517d);
#
#
#             var icon_b45bc0c51f658ad940b81f9f024b2396 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;diamond&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e56f4bb5f9780ec63dbecc63c52908aa.setIcon(icon_b45bc0c51f658ad940b81f9f024b2396);
#
#
#             marker_e56f4bb5f9780ec63dbecc63c52908aa.bindTooltip(
#                 `&lt;div&gt;
#                      EpicNice
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3e86d427fda640b7159af4d9dae6edf9 = L.marker(
#                 [37.781815, -122.401127],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_08d4f1ff39673f38d849ac0a62f0517d);
#
#
#             var icon_22e0fa21cc9adbda1a9db6758257612a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3e86d427fda640b7159af4d9dae6edf9.setIcon(icon_22e0fa21cc9adbda1a9db6758257612a);
#
#
#             marker_3e86d427fda640b7159af4d9dae6edf9.bindTooltip(
#                 `&lt;div&gt;
#                      AltSchool Yerba Buena
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a076c73268548623ddbe623c6e7ce0ca = L.marker(
#                 [37.78065, -122.400556],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_08d4f1ff39673f38d849ac0a62f0517d);
#
#
#             var icon_c565cd5e2ad7c3fd09c43afc90ff524b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a076c73268548623ddbe623c6e7ce0ca.setIcon(icon_c565cd5e2ad7c3fd09c43afc90ff524b);
#
#
#             marker_a076c73268548623ddbe623c6e7ce0ca.bindTooltip(
#                 `&lt;div&gt;
#                      San Francisco Unified School District
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_903a62d9fa22f6c1c1f19134879fef9b = L.marker(
#                 [37.786362, -122.405338],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_08d4f1ff39673f38d849ac0a62f0517d);
#
#
#             var icon_6f5c3892783a2858ef5eb9e7b4e95709 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_903a62d9fa22f6c1c1f19134879fef9b.setIcon(icon_6f5c3892783a2858ef5eb9e7b4e95709);
#
#
#             marker_903a62d9fa22f6c1c1f19134879fef9b.bindTooltip(
#                 `&lt;div&gt;
#                      American College of Early Childhood Education
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_501047dbdec25b06b4302c79605bdad7 = L.marker(
#                 [37.777146, -122.406228],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_08d4f1ff39673f38d849ac0a62f0517d);
#
#
#             var icon_2543b13edda0e0d5708b0ea818454f37 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,

# %% [markdown]
# # South San Francisco

# %%
map_sout_sanfran = createMap(south_sanfran_coord)
map_sout_sanfran_1 = addMarkers(south_sanfran_activities, map_sout_sanfran)
map_south_sanfran_2 = addMarkers(south_sanfran_companies, map_sout_sanfran_1)
map_south_sanfran_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c8aba771d9c8a28f4ab9bdc8f8647e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c8aba771d9c8a28f4ab9bdc8f8647e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8c8aba771d9c8a28f4ab9bdc8f8647e7 = L.map(
#                 &quot;map_8c8aba771d9c8a28f4ab9bdc8f8647e7&quot;,
#                 {
#                     center: [37.656246, -122.399735],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_8c8aba771d9c8a28f4ab9bdc8f8647e7);
#
#
#
#
#
#             var tile_layer_f11b5109bd5480b74afc800ad18d5bca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8c8aba771d9c8a28f4ab9bdc8f8647e7);
#
#
#             var marker_f241dd143febd8a18011839b40914c75 = L.marker(
#                 [37.656246, -122.399735],
#                 {}
#             ).addTo(map_8c8aba771d9c8a28f4ab9bdc8f8647e7);
#
#
#             var icon_987cf752b60563a97038a6466cf616f4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;diamond&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f241dd143febd8a18011839b40914c75.setIcon(icon_987cf752b60563a97038a6466cf616f4);
#
#
#             marker_f241dd143febd8a18011839b40914c75.bindTooltip(
#                 `&lt;div&gt;
#                      EpicNice
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_51f1fd5a4c45c68caad5ee55a675e5b2 = L.marker(
#                 [37.663471, -122.410062],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_8c8aba771d9c8a28f4ab9bdc8f8647e7);
#
#
#             var icon_dbc92b1c739f89941e5e90410d847eaf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_51f1fd5a4c45c68caad5ee55a675e5b2.setIcon(icon_dbc92b1c739f89941e5e90410d847eaf);
#
#
#             marker_51f1fd5a4c45c68caad5ee55a675e5b2.bindTooltip(
#                 `&lt;div&gt;
#                      Martin Elementary School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_86e22fe669514b18a324de6aec2d5dc0 = L.marker(
#                 [37.644996, -122.401457],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_8c8aba771d9c8a28f4ab9bdc8f8647e7);
#
#
#             var icon_7fa299c70a9501653b75802722617d00 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_86e22fe669514b18a324de6aec2d5dc0.setIcon(icon_7fa299c70a9501653b75802722617d00);
#
#
#             marker_86e22fe669514b18a324de6aec2d5dc0.bindTooltip(
#                 `&lt;div&gt;
#                      Academic Insight
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f32430ff3e3326f85ce7947c9d8a3715 = L.marker(
#                 [37.657254, -122.41528],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_8c8aba771d9c8a28f4ab9bdc8f8647e7);
#
#
#             var icon_82edf08da9789c4907dd39e9f1811c2d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f32430ff3e3326f85ce7947c9d8a3715.setIcon(icon_82edf08da9789c4907dd39e9f1811c2d);
#
#
#             marker_f32430ff3e3326f85ce7947c9d8a3715.bindTooltip(
#                 `&lt;div&gt;
#                      All Souls Catholic School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ee29bf4cd627fae5b77ca1ceadb5b89f = L.marker(
#                 [37.658973, -122.416312],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_8c8aba771d9c8a28f4ab9bdc8f8647e7);
#
#
#             var icon_8ba3d16c7fd76e9b7ab1c2ce89baf649 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );

# %%
map_south_sanfran_2.save('./images/south_sanfran_map.html')

# %% [markdown]
# # New York

# %%
map_newyork = createMap(newyork_coord)
map_newyork_1 = addMarkers(newyork_activities, map_newyork)
map_newyork_2 = addMarkers(newyork_companies, map_newyork_1)
map_newyork_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_655b24762066974935c7240da56e21ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_655b24762066974935c7240da56e21ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_655b24762066974935c7240da56e21ba = L.map(
#                 &quot;map_655b24762066974935c7240da56e21ba&quot;,
#                 {
#                     center: [40.73993, -73.993049],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_655b24762066974935c7240da56e21ba);
#
#
#
#
#
#             var tile_layer_2ffcf60977e294fbdc81cf880a7656c7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_655b24762066974935c7240da56e21ba);
#
#
#             var marker_b1bdd88ed713378823c6e288a2232731 = L.marker(
#                 [40.73993, -73.993049],
#                 {}
#             ).addTo(map_655b24762066974935c7240da56e21ba);
#
#
#             var icon_3ee5253c64abb3f54237be3fcd43ca42 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;diamond&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b1bdd88ed713378823c6e288a2232731.setIcon(icon_3ee5253c64abb3f54237be3fcd43ca42);
#
#
#             marker_b1bdd88ed713378823c6e288a2232731.bindTooltip(
#                 `&lt;div&gt;
#                      EpicNice
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d148ee1df4ff89835c8775dde7829d9b = L.marker(
#                 [40.740084, -73.99246],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_655b24762066974935c7240da56e21ba);
#
#
#             var icon_36b0694e26380727becfe603b8a3118d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d148ee1df4ff89835c8775dde7829d9b.setIcon(icon_36b0694e26380727becfe603b8a3118d);
#
#
#             marker_d148ee1df4ff89835c8775dde7829d9b.bindTooltip(
#                 `&lt;div&gt;
#                      Holocaust Education Foundation
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f43050ab7562d88a35b184f2547c08cd = L.marker(
#                 [40.738875, -73.993286],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_655b24762066974935c7240da56e21ba);
#
#
#             var icon_656d82edec95847c883c6691b56d50d8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f43050ab7562d88a35b184f2547c08cd.setIcon(icon_656d82edec95847c883c6691b56d50d8);
#
#
#             marker_f43050ab7562d88a35b184f2547c08cd.bindTooltip(
#                 `&lt;div&gt;
#                      Victory Schools
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_38a5a2c873d7792cdb85bfb8af9d1228 = L.marker(
#                 [40.739036, -73.995301],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_655b24762066974935c7240da56e21ba);
#
#
#             var icon_0cbf8989e82768a5b88f9183fe917b6d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_38a5a2c873d7792cdb85bfb8af9d1228.setIcon(icon_0cbf8989e82768a5b88f9183fe917b6d);
#
#
#             marker_38a5a2c873d7792cdb85bfb8af9d1228.bindTooltip(
#                 `&lt;div&gt;
#                      Ps 340
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d5b8795981848d4a20710433cbd24e6b = L.marker(
#                 [40.737837, -73.991761],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_655b24762066974935c7240da56e21ba);
#
#
#             var icon_bb39a9a3863cddad65e99374c5a29761 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d5b8795

# %%
map_newyork_2.save('./images/newyork_map.html')

# %% [markdown]
# # London

# %%
map_london = createMap(london_coord)
map_london_1 = addMarkers(london_activities, map_london)
map_london_2 = addMarkers(london_companies, map_london_1)
map_london_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10242a260dc7940a813334ae6e1542ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10242a260dc7940a813334ae6e1542ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_10242a260dc7940a813334ae6e1542ee = L.map(
#                 &quot;map_10242a260dc7940a813334ae6e1542ee&quot;,
#                 {
#                     center: [51.514165, -0.109017],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_10242a260dc7940a813334ae6e1542ee);
#
#
#
#
#
#             var tile_layer_d880103f357689e4a5b867854707d065 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_10242a260dc7940a813334ae6e1542ee);
#
#
#             var marker_4078994b80fef176bd66c8385df06df7 = L.marker(
#                 [51.514165, -0.109017],
#                 {}
#             ).addTo(map_10242a260dc7940a813334ae6e1542ee);
#
#
#             var icon_8c8a162f0bbc533c6969eaa959ac6388 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;diamond&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4078994b80fef176bd66c8385df06df7.setIcon(icon_8c8a162f0bbc533c6969eaa959ac6388);
#
#
#             marker_4078994b80fef176bd66c8385df06df7.bindTooltip(
#                 `&lt;div&gt;
#                      EpicNice
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_41dd6f56a400149acf918e2d48a5c549 = L.marker(
#                 [51.520223, -0.110579],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_10242a260dc7940a813334ae6e1542ee);
#
#
#             var icon_7ff96a7ed9cb10f0826beed4463d0565 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_41dd6f56a400149acf918e2d48a5c549.setIcon(icon_7ff96a7ed9cb10f0826beed4463d0565);
#
#
#             marker_41dd6f56a400149acf918e2d48a5c549.bindTooltip(
#                 `&lt;div&gt;
#                      St Albans Primary School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_03eb699ab724c758332b530e866ad87a = L.marker(
#                 [51.513546, -0.119311],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_10242a260dc7940a813334ae6e1542ee);
#
#
#             var icon_842e0bdb30644f2f28d79f685e401720 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_03eb699ab724c758332b530e866ad87a.setIcon(icon_842e0bdb30644f2f28d79f685e401720);
#
#
#             marker_03eb699ab724c758332b530e866ad87a.bindTooltip(
#                 `&lt;div&gt;
#                      St Clement Danes C of E Primary School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c414eba650389f6a75e7658cf419359c = L.marker(
#                 [51.516073, -0.121987],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_10242a260dc7940a813334ae6e1542ee);
#
#
#             var icon_d09b4cff7358a95bab8f495e97b6951b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c414eba650389f6a75e7658cf419359c.setIcon(icon_d09b4cff7358a95bab8f495e97b6951b);
#
#
#             marker_c414eba650389f6a75e7658cf419359c.bindTooltip(
#                 `&lt;div&gt;
#                      St Josephs R C Primary School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7fa1b6fa08d5a232027413dde63ab620 = L.marker(
#                 [51.522687, -0.112286],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_10242a260dc7940a813334ae6e1542ee);
#
#
#             var icon_e6cf70e6c3bd12992bdc7835195b0c78 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}

# %%
map_london_2.save('./images/london_map.html')
